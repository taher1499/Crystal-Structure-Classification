# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# pd.set_option('display.expand_frame_repr', True)

# %%
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
from matplotlib import rcParams
#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 4)
rcParams['figure.dpi'] = 150
#rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['font.size'] = 8
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
rcParams['axes.grid'] = True
rcParams['axes.facecolor'] = '#eeeeee'

# %%
df=pd.read_csv('data_perovskites.csv')

# %%
new_data=pd.read_csv('rhombohedral.csv')

# %%
en_bl=pd.read_csv('Electronegativity and bond lengths.csv')

# %%
#short=pd.read_csv('Paper_data.csv')

# %%
#short

# %%
#short=short[short['Lowest distortion']!='-']

# %%
#short=short[(short['tG'] >= 0.82) & (short['tG'] <= 1.1)]

# %%
#short=short[(short['μ'] >= 0.414) & (short['μ'] <= 0.732)]

# %%
#short=short[short['Valence A']!='not balanced']
#short=short[short['Valence A']!='element not in BV']

# %%
#short

# %%
#short.to_csv('short_list.csv')

# %%
wp1=df.drop(['Stability [eV/atom]','Magnetic moment [mu_B]','Volume per atom [A^3/atom]','a [ang]','b [ang]','c [ang]','alpha [deg]','beta [deg]','gamma [deg]','Vacancy energy [eV/O atom]','Band gap [eV]'],axis=1)

# %%
wp1=wp1[wp1['Lowest distortion']!='-']

# %%
wp1['Lowest distortion'].value_counts().sum()
# Out:
# 5276

# %%
wp1['Goldschmidt Tolerance']=(wp1['Radius A [ang]']+1.4)/((2**.5)*(wp1['Radius B [ang]']+1.4))

# %%
wp1['Octahedral factor']=(wp1['Radius B [ang]']/1.4)

# %%
wp1=wp1[(wp1['Goldschmidt Tolerance'] >= 0.82) & (wp1['Goldschmidt Tolerance'] <= 1.1)]

# %%
wp1=wp1[(wp1['Octahedral factor'] >= 0.414) & (wp1['Octahedral factor'] <= 0.732)]

# %%
wp1
# Out:
#      Chemical formula   A   B  In literature          Valence A  \
# 12             AcCoO3  Ac  Co          False  element not in BV
# 13             AcCrO3  Ac  Cr          False  element not in BV
# 15             AcCuO3  Ac  Cu          False  element not in BV
# 19             AcFeO3  Ac  Fe          False  element not in BV
# 20             AcGaO3  Ac  Ga          False  element not in BV
# ...               ...  ..  ..            ...                ...
# 5173           YbTiO3  Yb  Ti           True                  2
# 5177            YbVO3  Yb   V           True                  2
# 5178            YbWO3  Yb   W          False                  2
# 5182           YbZrO3  Yb  Zr          False                  2
# 5250            ZnVO3  Zn   V          False                  2
#
#               Valence B  Radius A [ang]  Radius B [ang] Lowest distortion  \
# 12    element not in BV            1.12            0.63      rhombohedral
# 13    element not in BV            1.12            0.58      orthorhombic
# 15    element not in BV            1.12            0.68      orthorhombic
# 19    element not in BV            1.12            0.67      orthorhombic
# 20    element not in BV            1.12            0.62      orthorhombic
# ...                 ...             ...             ...               ...
# 5173                  4            1.14            0.61      orthorhombic
# 5177                  4            1.14            0.58      orthorhombic
# 5178                  4            1.14            0.66      orthorhombic
# 5182                  4            1.14            0.72      orthorhombic
# 5250                  4            0.90            0.58             cubic
#
#      Formation energy [eV/atom]  Goldschmidt Tolerance  Octahedral factor
# 12                        -2.43               0.877788           0.450000
# 13                        -3.14               0.899954           0.414286
# 15                        -2.24               0.856687           0.485714
# 19                        -2.73               0.860826           0.478571
# 20                        -2.91               0.882133           0.442857
# ...                         ...                    ...                ...
# 5173                      -3.53               0.893558           0.435714
# 5177                      -3.07               0.907097           0.414286
# 5178                      -2.73               0.871870           0.471429
# 5182                      -3.66               0.847194           0.514286
# 5250                      -1.65               0.821387           0.414286
#
# [1251 rows x 12 columns]

# %%
wp1['Lowest distortion'].value_counts()* 100/1251
# Out:
# orthorhombic    52.757794
# cubic           37.889688
# rhombohedral     6.155076
# tetragonal       3.197442
# Name: Lowest distortion, dtype: float64

# %%
wp1=wp1[wp1['Valence A']!='not balanced']

# %%
wp1=wp1[wp1['Valence A']!='element not in BV']

# %%
#wp1=wp1[wp1['Valence A']!='4']

# %%
wp1
# Out:
#      Chemical formula   A   B  In literature Valence A Valence B  \
# 81             AgBiO3  Ag  Bi          False         1         5
# 107            AgMoO3  Ag  Mo          False         1         5
# 109            AgNbO3  Ag  Nb           True         1         5
# 122            AgReO3  Ag  Re          False         1         5
# 125            AgSbO3  Ag  Sb           True         1         5
# ...               ...  ..  ..            ...       ...       ...
# 5173           YbTiO3  Yb  Ti           True         2         4
# 5177            YbVO3  Yb   V           True         2         4
# 5178            YbWO3  Yb   W          False         2         4
# 5182           YbZrO3  Yb  Zr          False         2         4
# 5250            ZnVO3  Zn   V          False         2         4
#
#       Radius A [ang]  Radius B [ang] Lowest distortion  \
# 81              1.28            0.76      rhombohedral
# 107             1.28            0.61             cubic
# 109             1.28            0.64      rhombohedral
# 122             1.28            0.58             cubic
# 125             1.28            0.60      orthorhombic
# ...              ...             ...               ...
# 5173            1.14            0.61      orthorhombic
# 5177            1.14            0.58      orthorhombic
# 5178            1.14            0.66      orthorhombic
# 5182            1.14            0.72      orthorhombic
# 5250            0.90            0.58             cubic
#
#      Formation energy [eV/atom]  Goldschmidt Tolerance  Octahedral factor
# 81                        -0.82               0.877336           0.542857
# 107                       -1.55               0.942809           0.435714
# 109                       -2.01               0.928944           0.457143
# 122                       -1.22               0.957094           0.414286
# 125                       -1.16               0.947523           0.428571
# ...                         ...                    ...                ...
# 5173                      -3.53               0.893558           0.435714
# 5177                      -3.07               0.907097           0.414286
# 5178                      -2.73               0.871870           0.471429
# 5182                      -3.66               0.847194           0.514286
# 5250                      -1.65               0.821387           0.414286
#
# [675 rows x 12 columns]

# %%
wp1= pd.concat([wp1,pd.get_dummies(wp1['Valence A'])],axis=1)

# %%
wp1['Valence A']=pd.to_numeric(wp1['Valence A'],downcast='float')
wp1['Valence B']=pd.to_numeric(wp1['Valence B'],downcast='float')

# %%
wp1['Valence A'].value_counts()
# Out:
# 2.0    298
# 3.0    280
# 1.0     71
# 4.0     26
# Name: Valence A, dtype: int64

# %%
wp1['rA/rB']=wp1['Radius A [ang]']/wp1['Radius B [ang]']

# %%
wp1['ln rA/rB']=np.log(wp1['rA/rB'])

# %%
wp1['rA/rB'].describe()
# Out:
# count    675.000000
# mean       1.846269
# std        0.307426
# min        1.387755
# 25%        1.586853
# 50%        1.776316
# 75%        2.053640
# max        2.827586
# Name: rA/rB, dtype: float64

# %%
wp1['tN']=(1.4/wp1['Radius B [ang]'])-wp1['Valence A']*(wp1['Valence A']-(wp1['rA/rB']/wp1['ln rA/rB']))

# %%
wp1['tN'].describe()
# Out:
# count    675.000000
# mean       3.468194
# std        1.289246
# min       -2.238066
# 25%        2.824026
# 50%        3.821751
# 75%        4.229004
# max        5.863777
# Name: tN, dtype: float64

# %%
new_data=new_data[new_data['Valence A']!='not balanced']
new_data=new_data[new_data['Valence A']!='element not in BV']

# %%
new_data
# Out:
#         ABO3   A   B Valence A Valence B Lowest distortion  rA at 12 [ang]  \
# 76    AgAsO3  Ag  As         1         5        tetragonal            1.28
# 78     AgBO3  Ag   B         3         3             cubic            0.75
# 81    AgBiO3  Ag  Bi         1         5      rhombohedral            1.28
# 86    AgCrO3  Ag  Cr         1         5      orthorhombic            1.28
# 100   AgIrO3  Ag  Ir         1         5      rhombohedral            1.28
# ...      ...  ..  ..       ...       ...               ...             ...
# 5314  ZrTaO3  Zr  Ta         1         5             cubic            0.89
# 5319  ZrTiO3  Zr  Ti         2         4             cubic            0.89
# 5322   ZrUO3  Zr   U         1         5      orthorhombic            0.89
# 5323   ZrVO3  Zr   V         1         5             cubic            0.89
# 5324   ZrWO3  Zr   W         1         5             cubic            0.89
#
#       rA at 6 [ang]  rB at 6 [ang]           tG        tR Octahedral factor  \
# 76             0.95           0.46  1.018995909  0.923839       0.328571429
# 78             0.95           0.27  0.910484547  1.358334       0.192857143
# 81             0.95           0.76  0.877468699  0.911822       0.542857143
# 86             0.95           0.49  1.002821371  0.921930              0.35
# 100            0.95           0.57   0.96209766  0.917682       0.407142857
# ...             ...            ...          ...       ...               ...
# 5314           0.72           0.64  0.793881909  0.892546       0.457142857
# 5319           0.72           0.61  0.805730893  0.892978       0.435714286
# 5322           0.72           0.76  0.749777359  0.892076       0.542857143
# 5323           0.72           0.54  0.834803657  0.894528       0.385714286
# 5324           0.72           0.62  0.801742126  0.892819       0.442857143
#
#              VA         VB     VA/VB
# 76    45.369932   8.579808  5.287989
# 78    23.424975   6.209951  3.772168
# 81    45.369932  13.436928  3.376511
# 86    45.369932   9.001692  5.040156
# 100   45.369932  10.193831  4.450725
# ...         ...        ...       ...
# 5314  28.305459  11.319552  2.500581
# 5319  28.305459  10.827468  2.614227
# 5322  28.305459  13.436928  2.106542
# 5323  28.305459   9.735179  2.907544
# 5324  28.305459  10.989877  2.575594
#
# [2215 rows x 15 columns]

# %%
new_data=new_data[['ABO3','rA at 12 [ang]','rA at 6 [ang]','rB at 6 [ang]','VA/VB','tR','VA','VB']]

# %%
wp1=pd.merge(wp1,new_data,how='left',left_on='Chemical formula',right_on='ABO3')

# %%
en_bl.drop(['A','B'],axis=1)
# Out:
#         ABO3  EN of A  EN of B  Bond length of A  Bond length of B
# 0      Ac2O3     1.10     1.10           0.00000          0.000000
# 1     AcAgO3     1.10     1.93           0.00000          2.488353
# 2     AcAlO3     1.10     1.61           0.00000          1.892894
# 3     AcAsO3     1.10     2.18           0.00000          1.932227
# 4     AcAuO3     1.10     2.54           0.00000          2.313698
# ...      ...      ...      ...               ...               ...
# 5324   ZrWO3     1.33     2.36           2.38342          1.745600
# 5325   ZrYO3     1.33     1.22           2.38342          2.235124
# 5326  ZrYbO3     1.33     1.10           2.38342          2.223981
# 5327  ZrZnO3     1.33     1.65           2.38342          2.096141
# 5328   Zr2O3     1.33     1.33           2.38342          2.043778
#
# [5329 rows x 5 columns]

# %%
wp1=pd.merge(wp1,en_bl,how='left',left_on='Chemical formula',right_on='ABO3')

# %%
wp1
# Out:
#     Chemical formula A_x B_x  In literature  Valence A  Valence B  \
# 0             AgBiO3  Ag  Bi          False        1.0        5.0
# 1             AgMoO3  Ag  Mo          False        1.0        5.0
# 2             AgNbO3  Ag  Nb           True        1.0        5.0
# 3             AgReO3  Ag  Re          False        1.0        5.0
# 4             AgSbO3  Ag  Sb           True        1.0        5.0
# ..               ...  ..  ..            ...        ...        ...
# 670           YbTiO3  Yb  Ti           True        2.0        4.0
# 671            YbVO3  Yb   V           True        2.0        4.0
# 672            YbWO3  Yb   W          False        2.0        4.0
# 673           YbZrO3  Yb  Zr          False        2.0        4.0
# 674            ZnVO3  Zn   V          False        2.0        4.0
#
#      Radius A [ang]  Radius B [ang] Lowest distortion  \
# 0              1.28            0.76      rhombohedral
# 1              1.28            0.61             cubic
# 2              1.28            0.64      rhombohedral
# 3              1.28            0.58             cubic
# 4              1.28            0.60      orthorhombic
# ..              ...             ...               ...
# 670            1.14            0.61      orthorhombic
# 671            1.14            0.58      orthorhombic
# 672            1.14            0.66      orthorhombic
# 673            1.14            0.72      orthorhombic
# 674            0.90            0.58             cubic
#
#     Formation energy [eV/atom]  Goldschmidt Tolerance  Octahedral factor  1  \
# 0                        -0.82               0.877336           0.542857  1
# 1                        -1.55               0.942809           0.435714  1
# 2                        -2.01               0.928944           0.457143  1
# 3                        -1.22               0.957094           0.414286  1
# 4                        -1.16               0.947523           0.428571  1
# ..                         ...                    ...                ... ..
# 670                      -3.53               0.893558           0.435714  0
# 671                      -3.07               0.907097           0.414286  0
# 672                      -2.73               0.871870           0.471429  0
# 673                      -3.66               0.847194           0.514286  0
# 674                      -1.65               0.821387           0.414286  0
#
#      2  3  4     rA/rB  ln rA/rB        tN  ABO3_x  rA at 12 [ang]  \
# 0    0  0  0  1.684211  0.521297  4.072914  AgBiO3            1.28
# 1    0  0  0  2.098361  0.741156  4.126280  AgMoO3            1.28
# 2    0  0  0  2.000000  0.693147  4.072890  AgNbO3            1.28
# 3    0  0  0  2.206897  0.791587  4.201732  AgReO3            1.28
# 4    0  0  0  2.133333  0.757686  4.148925  AgSbO3            1.28
# ..  .. .. ..       ...       ...       ...     ...             ...
# 670  1  0  0  1.868852  0.625325  4.272306  YbTiO3            1.14
# 671  1  0  0  1.965517  0.675755  4.231037   YbVO3            1.14
# 672  1  0  0  1.727273  0.546544  4.441924   YbWO3            1.14
# 673  1  0  0  1.583333  0.459532  4.835508  YbZrO3            1.14
# 674  1  0  0  1.551724  0.439367  5.477252   ZnVO3            0.90
#
#      rA at 6 [ang]  rB at 6 [ang]     VA/VB        tR         VA         VB  \
# 0             0.95           0.76  3.376511  0.911822  45.369932  13.436928
# 1             0.95           0.61  4.190262  0.915983  45.369932  10.827468
# 2             0.95           0.64  4.008103  0.914881  45.369932  11.319552
# 3             0.95           0.58  4.383629  0.917231  45.369932  10.349856
# 4             0.95           0.60  4.253431  0.916382  45.369932  10.666667
# ..             ...            ...       ...       ...        ...        ...
# 670           0.95           0.61  3.567286  0.989479  38.624680  10.827468
# 671           0.95           0.58  3.731905  0.990588  38.624680  10.349856
# 672           0.95           0.66  3.313786  0.987975  38.624680  11.655755
# 673           0.95           0.72  3.040315  0.986701  38.624680  12.704171
# 674           0.74           0.58  2.770850  0.910932  28.677894  10.349856
#
#      ABO3_y A_y B_y  EN of A  EN of B  Bond length of A  Bond length of B
# 0    AgBiO3  Ag  Bi     1.93     2.02          2.761453          2.215655
# 1    AgMoO3  Ag  Mo     1.93     2.16          2.761453          1.789300
# 2    AgNbO3  Ag  Nb     1.93     1.60          2.761453          1.955055
# 3    AgReO3  Ag  Re     1.93     1.90          2.761453          1.987971
# 4    AgSbO3  Ag  Sb     1.93     2.05          2.761453          2.075849
# ..      ...  ..  ..      ...      ...               ...               ...
# 670  YbTiO3  Yb  Ti     1.10     1.54          2.519261          1.927849
# 671   YbVO3  Yb   V     1.10     1.63          2.519261          1.758039
# 672   YbWO3  Yb   W     1.10     2.36          2.519261          1.745600
# 673  YbZrO3  Yb  Zr     1.10     1.33          2.519261          2.043778
# 674   ZnVO3  Zn   V     1.65     1.63          2.375479          1.758039
#
# [675 rows x 34 columns]

# %%
wp1['Bond length of A'].value_counts()
# Out:
# 2.689119    43
# 2.577786    42
# 2.514402    41
# 2.617634    39
# 2.675988    28
# 2.611965    27
# 2.645083    26
# 2.546312    25
# 2.571812    23
# 2.942999    22
# 2.519261    22
# 2.550861    22
# 2.659877    22
# 2.768351    22
# 2.568546    21
# 2.648078    21
# 2.582926    20
# 2.536253    20
# 2.411516    20
# 2.557065    20
# 2.344467    20
# 2.566449    19
# 2.500930    16
# 2.645968    16
# 2.531967    15
# 2.393444     9
# 2.472899     9
# 2.761453     8
# 2.759925     8
# 3.025719     7
# 3.112266     6
# 2.392362     5
# 2.290644     3
# 2.453212     3
# 3.300176     3
# 2.233563     1
# 2.375479     1
# Name: Bond length of A, dtype: int64

# %%
#wp1['New Tolerance Factor']=((wp1['rA at 6 [ang]']/wp1['rA at 12 [ang]'])/3)*((wp1['Radius A [ang]']+1.4)/(wp1['Radius B [ang]']+1.4))*((wp1['Radius B [ang]']+1.4)/1.4*(2**0.5))*((wp1['Radius A [ang]']+1.4)/1.4*(2**0.5))

# %%
wp1['EN diff with radius']=((wp1['Radius B [ang]']/1.4)*(wp1['EN of B']-3.44)+(wp1['Radius A [ang]']/1.4)*(wp1['EN of A']-6.88))

# %%
#wp1.drop(['ABO3_x','Radius A [ang]','Radius B [ang]','VA/VB','tR','VA','VB','ABO3_y','A_y','B_y'],axis=1,inplace=True)

# %%
#wp1.rename(columns={'B_x':'B','A_x':'A',"Goldschmidt Tolerance": "tG", "Octahedral factor": "μ",'EN diff with radius':'ΔENR','Bond length of B':'l(B-O)','Bond length of A':'l(A-O)','EN of B':'EN(B)','EN of A':'EN(A)','rA at 6 [ang]':'r(AVI)','rA at 12 [ang]':'r(AXII)','rB at 6 [ang]':'r(BVI)'},inplace=True)

# %%
wp1[wp1['Chemical formula']=="LaZrO3"]
# Out:
#     Chemical formula A_x B_x  In literature  Valence A  Valence B  \
# 350           LaZrO3  La  Zr          False        3.0        3.0
#
#      Radius A [ang]  Radius B [ang] Lowest distortion  \
# 350            1.36            0.72      orthorhombic
#
#     Formation energy [eV/atom]  Goldschmidt Tolerance  Octahedral factor  1  \
# 350                      -3.42               0.920573           0.514286  0
#
#      2  3  4     rA/rB  ln rA/rB        tN  ABO3_x  rA at 12 [ang]  \
# 350  0  1  0  1.888889  0.635989  1.854455  LaZrO3            1.36
#
#      rA at 6 [ang]  rB at 6 [ang]     VA/VB        tR         VA         VB  \
# 350           1.03           0.72  3.900719  0.950991  49.555401  12.704171
#
#      ABO3_y A_y B_y  EN of A  EN of B  Bond length of A  Bond length of B  \
# 350  LaZrO3  La  Zr      1.1     1.33          2.689119          2.043778
#
#      EN diff with radius
# 350                 -6.7

# %%
#temp_og=wp1[['Chemical formula','EN diff with radius']]

# %%
#temp_ng=pd.read_csv('temp.csv')

# %%
#temp_ng=temp_ng[['Perovskite','EN diff with radius']]

# %%
#temp_ng

# %%
#basic=pd.merge(temp_ng,temp_og,how='left',left_on='Perovskite',right_on='Chemical formula')

# %%
#basic

# %%
#basic.to_csv('en_mixup.csv')

# %%
#rhom=wp1[wp1['Lowest distortion']=='rhombohedral']

# %%
#rhom.to_csv('wp2.csv')

# %%
#wp1.to_csv('Draft data.csv')

# %%
wp1['1'].dtypes
# Out:
# dtype('uint8')

# %%
#draft=pd.read_csv('Draft data.csv')

# %%
#draft

# %%
#temp=wp1[['Chemical formula','tN']]

# %%
#temp2=pd.merge(draft,temp,how='left',on='Chemical formula')

# %%
#temp2

# %%
#temp2.replace([np.inf, -np.inf], np.nan,inplace=True)

# %%
#temp2['tN'].fillna('-',inplace=True)

# %%
#temp2.to_csv('Paper_data.csv')

# %%
wp1['Formation energy [eV/atom]'].dtype
# Out:
# dtype('O')

# %%
wp1['Formation energy [eV/atom]']=pd.to_numeric(wp1['Formation energy [eV/atom]'],downcast='float')

# %%
wp1['Formation energy [eV/atom]'].describe()
# Out:
# count    675.000000
# mean      -2.364119
# std        0.715403
# min       -3.840000
# 25%       -2.905000
# 50%       -2.370000
# 75%       -1.885000
# max       -0.220000
# Name: Formation energy [eV/atom], dtype: float64

# %%
sns.kdeplot(wp1['Formation energy [eV/atom]'])
plt.title('Formation energy')
# Out:
# Text(0.5, 1.0, 'Formation energy')

# %%
categorical = wp1.select_dtypes(include=[np.object,np.bool])

numeric = wp1.select_dtypes(include=[np.int,np.float32,np.float,np.int32,np.uint8])
numeric_cols = numeric.columns

# %%
categorical
# Out:
#     Chemical formula A_x B_x  In literature Lowest distortion  ABO3_x  ABO3_y  \
# 0             AgBiO3  Ag  Bi          False      rhombohedral  AgBiO3  AgBiO3
# 1             AgMoO3  Ag  Mo          False             cubic  AgMoO3  AgMoO3
# 2             AgNbO3  Ag  Nb           True      rhombohedral  AgNbO3  AgNbO3
# 3             AgReO3  Ag  Re          False             cubic  AgReO3  AgReO3
# 4             AgSbO3  Ag  Sb           True      orthorhombic  AgSbO3  AgSbO3
# ..               ...  ..  ..            ...               ...     ...     ...
# 670           YbTiO3  Yb  Ti           True      orthorhombic  YbTiO3  YbTiO3
# 671            YbVO3  Yb   V           True      orthorhombic   YbVO3   YbVO3
# 672            YbWO3  Yb   W          False      orthorhombic   YbWO3   YbWO3
# 673           YbZrO3  Yb  Zr          False      orthorhombic  YbZrO3  YbZrO3
# 674            ZnVO3  Zn   V          False             cubic   ZnVO3   ZnVO3
#
#     A_y B_y
# 0    Ag  Bi
# 1    Ag  Mo
# 2    Ag  Nb
# 3    Ag  Re
# 4    Ag  Sb
# ..   ..  ..
# 670  Yb  Ti
# 671  Yb   V
# 672  Yb   W
# 673  Yb  Zr
# 674  Zn   V
#
# [675 rows x 9 columns]

# %%
numeric
# Out:
#      Valence A  Valence B  Radius A [ang]  Radius B [ang]  \
# 0          1.0        5.0            1.28            0.76
# 1          1.0        5.0            1.28            0.61
# 2          1.0        5.0            1.28            0.64
# 3          1.0        5.0            1.28            0.58
# 4          1.0        5.0            1.28            0.60
# ..         ...        ...             ...             ...
# 670        2.0        4.0            1.14            0.61
# 671        2.0        4.0            1.14            0.58
# 672        2.0        4.0            1.14            0.66
# 673        2.0        4.0            1.14            0.72
# 674        2.0        4.0            0.90            0.58
#
#      Goldschmidt Tolerance  Octahedral factor  1  2  3  4     rA/rB  ln rA/rB  \
# 0                 0.877336           0.542857  1  0  0  0  1.684211  0.521297
# 1                 0.942809           0.435714  1  0  0  0  2.098361  0.741156
# 2                 0.928944           0.457143  1  0  0  0  2.000000  0.693147
# 3                 0.957094           0.414286  1  0  0  0  2.206897  0.791587
# 4                 0.947523           0.428571  1  0  0  0  2.133333  0.757686
# ..                     ...                ... .. .. .. ..       ...       ...
# 670               0.893558           0.435714  0  1  0  0  1.868852  0.625325
# 671               0.907097           0.414286  0  1  0  0  1.965517  0.675755
# 672               0.871870           0.471429  0  1  0  0  1.727273  0.546544
# 673               0.847194           0.514286  0  1  0  0  1.583333  0.459532
# 674               0.821387           0.414286  0  1  0  0  1.551724  0.439367
#
#            tN  rA at 12 [ang]  rA at 6 [ang]  rB at 6 [ang]     VA/VB  \
# 0    4.072914            1.28           0.95           0.76  3.376511
# 1    4.126280            1.28           0.95           0.61  4.190262
# 2    4.072890            1.28           0.95           0.64  4.008103
# 3    4.201732            1.28           0.95           0.58  4.383629
# 4    4.148925            1.28           0.95           0.60  4.253431
# ..        ...             ...            ...            ...       ...
# 670  4.272306            1.14           0.95           0.61  3.567286
# 671  4.231037            1.14           0.95           0.58  3.731905
# 672  4.441924            1.14           0.95           0.66  3.313786
# 673  4.835508            1.14           0.95           0.72  3.040315
# 674  5.477252            0.90           0.74           0.58  2.770850
#
#            tR         VA         VB  EN of A  EN of B  Bond length of A  \
# 0    0.911822  45.369932  13.436928     1.93     2.02          2.761453
# 1    0.915983  45.369932  10.827468     1.93     2.16          2.761453
# 2    0.914881  45.369932  11.319552     1.93     1.60          2.761453
# 3    0.917231  45.369932  10.349856     1.93     1.90          2.761453
# 4    0.916382  45.369932  10.666667     1.93     2.05          2.761453
# ..        ...        ...        ...      ...      ...               ...
# 670  0.989479  38.624680  10.827468     1.10     1.54          2.519261
# 671  0.990588  38.624680  10.349856     1.10     1.63          2.519261
# 672  0.987975  38.624680  11.655755     1.10     2.36          2.519261
# 673  0.986701  38.624680  12.704171     1.10     1.33          2.519261
# 674  0.910932  28.677894  10.349856     1.65     1.63          2.375479
#
#      Bond length of B  EN diff with radius
# 0            2.215655            -5.296571
# 1            1.789300            -5.083429
# 2            1.955055            -5.366857
# 3            1.987971            -5.163714
# 4            2.075849            -5.121429
# ..                ...                  ...
# 670          1.927849            -5.534429
# 671          1.758039            -5.456429
# 672          1.745600            -5.215714
# 673          2.043778            -5.791714
# 674          1.758039            -4.112000
#
# [675 rows x 25 columns]

# %%
corr = numeric.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col2 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col4 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col5 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col7 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col8 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col9 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col10 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col11 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col13 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col14 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col15 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col16 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col17 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col18 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col19 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col20 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col21 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col22 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col23 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row0_col24 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col2 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col4 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col5 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col6 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col7 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col10 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col11 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col12 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col13 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col14 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col15 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col16 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col17 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col18 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col19 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col20 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col21 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col22 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col23 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row1_col24 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col1 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col3 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col4 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col5 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col6 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col7 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col8 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_1b207ccc_d212_11ea_a43f_30e37ac86bc0row2_col9 {
#             background-color:  #86a9fc;

# %%
import re
regex = re.compile(r"\[|\]|<", re.IGNORECASE)

# %%
numeric.columns = [regex.sub("_", col) if any(x in str(col) for x in set(('[', ']', '<'))) else col for col in numeric.columns.values]

# %%
test=wp1

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.preprocessing import LabelEncoder

# %%
le_target = LabelEncoder()
test['Lowest distortion']= le_target.fit_transform(test['Lowest distortion'])

# %%
numeric
# Out:
#      Valence A  Valence B  Radius A _ang_  Radius B _ang_  \
# 0          1.0        5.0            1.28            0.76
# 1          1.0        5.0            1.28            0.61
# 2          1.0        5.0            1.28            0.64
# 3          1.0        5.0            1.28            0.58
# 4          1.0        5.0            1.28            0.60
# ..         ...        ...             ...             ...
# 670        2.0        4.0            1.14            0.61
# 671        2.0        4.0            1.14            0.58
# 672        2.0        4.0            1.14            0.66
# 673        2.0        4.0            1.14            0.72
# 674        2.0        4.0            0.90            0.58
#
#      Goldschmidt Tolerance  Octahedral factor  1  2  3  4     rA/rB  ln rA/rB  \
# 0                 0.877336           0.542857  1  0  0  0  1.684211  0.521297
# 1                 0.942809           0.435714  1  0  0  0  2.098361  0.741156
# 2                 0.928944           0.457143  1  0  0  0  2.000000  0.693147
# 3                 0.957094           0.414286  1  0  0  0  2.206897  0.791587
# 4                 0.947523           0.428571  1  0  0  0  2.133333  0.757686
# ..                     ...                ... .. .. .. ..       ...       ...
# 670               0.893558           0.435714  0  1  0  0  1.868852  0.625325
# 671               0.907097           0.414286  0  1  0  0  1.965517  0.675755
# 672               0.871870           0.471429  0  1  0  0  1.727273  0.546544
# 673               0.847194           0.514286  0  1  0  0  1.583333  0.459532
# 674               0.821387           0.414286  0  1  0  0  1.551724  0.439367
#
#            tN  rA at 12 _ang_  rA at 6 _ang_  rB at 6 _ang_     VA/VB  \
# 0    4.072914            1.28           0.95           0.76  3.376511
# 1    4.126280            1.28           0.95           0.61  4.190262
# 2    4.072890            1.28           0.95           0.64  4.008103
# 3    4.201732            1.28           0.95           0.58  4.383629
# 4    4.148925            1.28           0.95           0.60  4.253431
# ..        ...             ...            ...            ...       ...
# 670  4.272306            1.14           0.95           0.61  3.567286
# 671  4.231037            1.14           0.95           0.58  3.731905
# 672  4.441924            1.14           0.95           0.66  3.313786
# 673  4.835508            1.14           0.95           0.72  3.040315
# 674  5.477252            0.90           0.74           0.58  2.770850
#
#            tR         VA         VB  EN of A  EN of B  Bond length of A  \
# 0    0.911822  45.369932  13.436928     1.93     2.02          2.761453
# 1    0.915983  45.369932  10.827468     1.93     2.16          2.761453
# 2    0.914881  45.369932  11.319552     1.93     1.60          2.761453
# 3    0.917231  45.369932  10.349856     1.93     1.90          2.761453
# 4    0.916382  45.369932  10.666667     1.93     2.05          2.761453
# ..        ...        ...        ...      ...      ...               ...
# 670  0.989479  38.624680  10.827468     1.10     1.54          2.519261
# 671  0.990588  38.624680  10.349856     1.10     1.63          2.519261
# 672  0.987975  38.624680  11.655755     1.10     2.36          2.519261
# 673  0.986701  38.624680  12.704171     1.10     1.33          2.519261
# 674  0.910932  28.677894  10.349856     1.65     1.63          2.375479
#
#      Bond length of B  EN diff with radius
# 0            2.215655            -5.296571
# 1            1.789300            -5.083429
# 2            1.955055            -5.366857
# 3            1.987971            -5.163714
# 4            2.075849            -5.121429
# ..                ...                  ...
# 670          1.927849            -5.534429
# 671          1.758039            -5.456429
# 672          1.745600            -5.215714
# 673          2.043778            -5.791714
# 674          1.758039            -4.112000
#
# [675 rows x 25 columns]

# %%
categorical
# Out:
#     Chemical formula A_x B_x  In literature Lowest distortion  ABO3_x  ABO3_y  \
# 0             AgBiO3  Ag  Bi          False      rhombohedral  AgBiO3  AgBiO3
# 1             AgMoO3  Ag  Mo          False             cubic  AgMoO3  AgMoO3
# 2             AgNbO3  Ag  Nb           True      rhombohedral  AgNbO3  AgNbO3
# 3             AgReO3  Ag  Re          False             cubic  AgReO3  AgReO3
# 4             AgSbO3  Ag  Sb           True      orthorhombic  AgSbO3  AgSbO3
# ..               ...  ..  ..            ...               ...     ...     ...
# 670           YbTiO3  Yb  Ti           True      orthorhombic  YbTiO3  YbTiO3
# 671            YbVO3  Yb   V           True      orthorhombic   YbVO3   YbVO3
# 672            YbWO3  Yb   W          False      orthorhombic   YbWO3   YbWO3
# 673           YbZrO3  Yb  Zr          False      orthorhombic  YbZrO3  YbZrO3
# 674            ZnVO3  Zn   V          False             cubic   ZnVO3   ZnVO3
#
#     A_y B_y
# 0    Ag  Bi
# 1    Ag  Mo
# 2    Ag  Nb
# 3    Ag  Re
# 4    Ag  Sb
# ..   ..  ..
# 670  Yb  Ti
# 671  Yb   V
# 672  Yb   W
# 673  Yb  Zr
# 674  Zn   V
#
# [675 rows x 9 columns]

# %%
X=numeric.drop(['Radius A _ang_','Radius B _ang_','VA/VB','tR','VA','VB','rB at 6 _ang_','4','Valence A','Valence B','rA/rB','ln rA/rB'],axis=1)
y=test['Lowest distortion']

# %%
X
# Out:
#      Goldschmidt Tolerance  Octahedral factor  1  2  3        tN  \
# 0                 0.877336           0.542857  1  0  0  4.072914
# 1                 0.942809           0.435714  1  0  0  4.126280
# 2                 0.928944           0.457143  1  0  0  4.072890
# 3                 0.957094           0.414286  1  0  0  4.201732
# 4                 0.947523           0.428571  1  0  0  4.148925
# ..                     ...                ... .. .. ..       ...
# 670               0.893558           0.435714  0  1  0  4.272306
# 671               0.907097           0.414286  0  1  0  4.231037
# 672               0.871870           0.471429  0  1  0  4.441924
# 673               0.847194           0.514286  0  1  0  4.835508
# 674               0.821387           0.414286  0  1  0  5.477252
#
#      rA at 12 _ang_  rA at 6 _ang_  EN of A  EN of B  Bond length of A  \
# 0              1.28           0.95     1.93     2.02          2.761453
# 1              1.28           0.95     1.93     2.16          2.761453
# 2              1.28           0.95     1.93     1.60          2.761453
# 3              1.28           0.95     1.93     1.90          2.761453
# 4              1.28           0.95     1.93     2.05          2.761453
# ..              ...            ...      ...      ...               ...
# 670            1.14           0.95     1.10     1.54          2.519261
# 671            1.14           0.95     1.10     1.63          2.519261
# 672            1.14           0.95     1.10     2.36          2.519261
# 673            1.14           0.95     1.10     1.33          2.519261
# 674            0.90           0.74     1.65     1.63          2.375479
#
#      Bond length of B  EN diff with radius
# 0            2.215655            -5.296571
# 1            1.789300            -5.083429
# 2            1.955055            -5.366857
# 3            1.987971            -5.163714
# 4            2.075849            -5.121429
# ..                ...                  ...
# 670          1.927849            -5.534429
# 671          1.758039            -5.456429
# 672          1.745600            -5.215714
# 673          2.043778            -5.791714
# 674          1.758039            -4.112000
#
# [675 rows x 13 columns]

# %%
#X.rename(columns={"Goldschmidt Tolerance": "tG", "Octahedral factor": "μ",'EN diff with radius':'ΔENR','Bond length of B':'l(B-O)','Bond length of A':'l(A-O)','EN of B':'EN(B)','EN of A':'EN(A)','rA at 6 _ang_':'r(A$_{VI}$)','rA at 12 _ang_':'r(A$_{XII}$)','1':'v(A$^{1+}$)','2':'v(A$^{2+}$)','3':'v(A$^{3+}$)','tN':'τ'},inplace=True)

# %%
corr = X.corr(method='spearman')
corr.style.background_gradient(cmap='coolwarm')
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col2 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col3 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col4 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col5 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col6 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col7 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col8 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col9 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col10 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col11 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row0_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col2 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col3 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col4 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col5 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col6 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col8 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col10 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col11 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row1_col12 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col0 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col3 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col4 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col5 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col6 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col7 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col8 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col9 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col10 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col11 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row2_col12 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col0 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col1 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col5 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col6 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col7 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col8 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col9 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col10 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col11 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row3_col12 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col0 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col1 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col6 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_258844ca_d212_11ea_b397_30e37ac86bc0row4_col7 {
#             background-color:  #7ea1fa;
#             color:

# %%
fig, ax = plt.subplots()
#plt.figure(figsize=(20,20))
sns.heatmap(X.corr(method='spearman'), annot=True, fmt='.2f', 
            cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax)
sns.set(font_scale=1)
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
ax.set_xticklabels(ax.get_xticklabels(), rotation="vertical")

#plt.savefig('result4.tif', bbox_inches='tight', pad_inches=0.0)
# Out:
# [Text(0.5, 0, 'Goldschmidt Tolerance'),
#  Text(1.5, 0, 'Octahedral factor'),
#  Text(2.5, 0, '1'),
#  Text(3.5, 0, '2'),
#  Text(4.5, 0, '3'),
#  Text(5.5, 0, 'tN'),
#  Text(6.5, 0, 'rA at 12 _ang_'),
#  Text(7.5, 0, 'rA at 6 _ang_'),
#  Text(8.5, 0, 'EN of A'),
#  Text(9.5, 0, 'EN of B'),
#  Text(10.5, 0, 'Bond length of A'),
#  Text(11.5, 0, 'Bond length of B'),
#  Text(12.5, 0, 'EN diff with radius')]

# %%
test['Lowest distortion'].value_counts()
# Out:
# 1    362
# 0    261
# 2     33
# 3     19
# Name: Lowest distortion, dtype: int64

# %%
categorical['Lowest distortion'].value_counts()
# Out:
# orthorhombic    362
# cubic           261
# rhombohedral     33
# tetragonal       19
# Name: Lowest distortion, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
train_data = pd.concat([X_train, y_train], axis=1)

# %%
y_train.value_counts()
# Out:
# 1    242
# 0    179
# 2     22
# 3      9
# Name: Lowest distortion, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    120
# 0     82
# 2     11
# 3     10
# Name: Lowest distortion, dtype: int64

# %%
cubic = train_data[train_data['Lowest distortion']==0]
orthorhombic = train_data[train_data['Lowest distortion']==1]
rhombohedral = train_data[train_data['Lowest distortion']==2]
tetragonal= train_data[train_data['Lowest distortion']==3]

# %%
# upsample minority
rho_upsampled = resample(rhombohedral,
 replace=True, # sample with replacement
 n_samples=len(orthorhombic), # match number in majority class
 random_state=27) # reproducible results

# upsample minority
tetra_upsampled = resample(tetragonal,
 replace=True, # sample with replacement
 n_samples=len(orthorhombic), # match number in majority class
 random_state=27) # reproducible results

# upsample minority
cubic_upsampled = resample(cubic,
 replace=True, # sample with replacement
 n_samples=len(orthorhombic), # match number in majority class
 random_state=27) # reproducible results

# %%
upsampled = pd.concat([orthorhombic, rho_upsampled, cubic_upsampled, tetra_upsampled])

# %%
upsampled['Lowest distortion'].value_counts()
# Out:
# 3    242
# 2    242
# 1    242
# 0    242
# Name: Lowest distortion, dtype: int64

# %%
X_new=upsampled.drop('Lowest distortion',axis=1)
y_new=upsampled['Lowest distortion']

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score

# %%
classifiers=list()
model1 = XGBClassifier()
classifiers.append(model1)
model2 = svm.SVC()
classifiers.append(model2)
model3 = tree.DecisionTreeClassifier()
classifiers.append(model3)
model4 = RandomForestClassifier()
classifiers.append(model4)

# %%
classifiers
# Out:
# [XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, gamma=0,
#                learning_rate=0.1, max_delta_step=0, max_depth=3,
#                min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#                nthread=None, objective='binary:logistic', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=1, verbosity=1),
#  SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#      decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#      max_iter=-1, probability=False, random_state=None, shrinking=True,
#      tol=0.001, verbose=False),
#  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best'),
#  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                         criterion='gini', max_depth=None, max_features='auto',
#                         max_leaf_nodes=None, max_samples=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, n_estimators=100,
#                         n_jobs=None, oob_score=False, random_state=None,
#                         verbose=0, warm_start=False)]

# %% [markdown]
# ## SVM

# %%
model2.fit(X_new, y_new)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model2.score(X_new,y_new)
# Out:
# 0.5681818181818182

# %%
model2.score(X_test,y_test)
# Out:
# 0.6412556053811659

# %%
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score

preds = model2.predict(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.6412556053811659

# %%
confusion_matrix(preds,y_test)
# Out:
# array([[53, 17,  2,  1],
#        [12, 64,  2,  1],
#        [16, 36,  5,  4],
#        [ 1,  3,  2,  4]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# 1    120
# 0     82
# 2     11
# 3     10
# Name: Lowest distortion, dtype: int64

# %%
pd.Series(preds).value_counts()
# Out:
# 1    79
# 0    73
# 2    61
# 3    10
# dtype: int64

# %%
# ACC should be above 463/731 which is 63.33%
# ACC should be above 764/1221 which is 62.57% IN the case of taking the values within TG and OF limits


#With valence
#acc=0.5636114911080712
#array([[266,  56,  21,   2],
 #      [125, 132,   9,   3],
  #     [ 45,  19,   8,   2],
   #    [ 27,   6,   4,   6]], dtype=int64)
    
#Without valence
#acc=0.5636114911080712

#array([[682, 118,  33,  11],
#       [144, 237,  28,   6],
#       [164, 114,  42,   0],
#       [ 88,  41,  10,  24]], dtype=int64)

#only real values
#acc=0.6285714285714286
#array([[ 3, 19,  1,  1],
 #      [ 2, 41,  2,  0],
  #     [ 0,  0,  0,  0],
    #   [ 0,  0,  1,  0]], dtype=int64)
    
#using VA/VB
#acc=0.5690834473324213
#array([[279,  56,  11,   2],
#       [ 84, 114,   8,   4],
#       [ 80,  27,  18,   2],
#       [ 20,  16,   5,   5]], dtype=int64)

#Using en and bl
#acc=0.5677154582763337

#using Va and VB
#acc=0.5622435020519836

#limits TG .6 to 1.1
        # OF .414 to .732
##acc within the limits =0.49303849303849306 and ignoring valencies
## taking valencies 0.5617173524150268
# 336/559 acc should be greater than this for valencies and and limits THAT is 60.1%

#One hot encoding decreased the acc to 0.5366726296958855

#limits TG .8 to 1.05
        # OF .414 to .732
    #acc=0.5870445344129555

# %% [markdown]
# ## XGBoost

# %%
model1.fit(X_new, y_new)
model1.score(X_new,y_new)
# Out:
# 0.9679752066115702

# %%
model1.score(X_test,y_test)
# Out:
# 0.7982062780269058

# %%
preds = model1.predict(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.7982062780269058

# %%
confusion_matrix(preds,y_test)
# Out:
# array([[ 67,  11,   1,   2],
#        [ 11, 102,   3,   1],
#        [  3,   6,   6,   4],
#        [  1,   1,   1,   3]], dtype=int64)

# %%
y_test.value_counts()
# Out:
# 1    120
# 0     82
# 2     11
# 3     10
# Name: Lowest distortion, dtype: int64

# %%
features = X_new.columns
importances = model1.feature_importances_
indices = np.argsort(importances)

#plt.figure(figsize=(6,7))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
#acc with only valence A = 0.6607387140902873
#array([[327,  48,   7,   0],
#       [ 74, 121,   8,   0],
#       [ 38,  27,  25,   3],
#       [ 24,  17,   2,  10]], dtype=int64)

#using VA/VB
#0.6566347469220246

#Without taking the valencies 
#acc=0.6061997703788748

# New tolerance factor performs better than tR
##takin en and bl
#acc=0.7209302325581395

#VA/VB and Valence B do not have any effect

# VA and VB also have no effect in the prediction and rB at 6 also has no effect
#acc=0.719562243502052

#limits TG .6 to 1.1
        # OF .414 to .732
## When taking the limits acc fell to 0.6920556920556921 and ignoring valencies
# limits and valencies gives highest acc yet 0.7638640429338104

# on hot enconding on valence A gives best acc yet =0.7656529516994633 this is in additional to the limits and removing empty valence values
# introducing EN diff gives acc=0.7692307692307693
#taking en diff with with radius multiplied increased the acc to = 0.774597495527728

#when

# %% [markdown]
# ## Decision Tree

# %%
model3.fit(X_new, y_new)
model3.score(X_new,y_new)
# Out:
# 1.0

# %%
model3.score(X_test,y_test)
# Out:
# 0.6771300448430493

# %%
preds = model3.predict(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.6771300448430493

# %%
confusion_matrix(preds,y_test)
# Out:
# array([[55, 16,  1,  1],
#        [24, 91,  6,  5],
#        [ 2, 10,  3,  2],
#        [ 1,  3,  1,  2]], dtype=int64)

# %%
pd.Series(preds).value_counts()
# Out:
# 1    126
# 0     73
# 2     17
# 3      7
# dtype: int64

# %% [markdown]
# ## Random Forest

# %%
model4.fit(X_new, y_new)
model4.score(X_new,y_new)
# Out:
# 1.0

# %%
model4.score(X_test,y_test)
# Out:
# 0.7713004484304933

# %%
accuracy_score(preds,y_test)
# Out:
# 0.6771300448430493

# %%
confusion_matrix(preds,y_test)
# Out:
# array([[55, 16,  1,  1],
#        [24, 91,  6,  5],
#        [ 2, 10,  3,  2],
#        [ 1,  3,  1,  2]], dtype=int64)

# %%
features = X_new.columns
importances = model4.feature_importances_
indices = np.argsort(importances)

#plt.figure(figsize=(6,7))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
importances
# Out:
# array([0.1435025 , 0.0680385 , 0.01088919, 0.01238781, 0.01441049,
#        0.10789687, 0.07193469, 0.09799408, 0.08863901, 0.0914133 ,
#        0.09201984, 0.07775012, 0.12312359])

# %%
#with both valence a and b
#0.7113543091655267
#array([[381,  71,  10,   4],
#       [ 64, 113,   9,   3],
#       [ 13,  21,  22,   2],
#       [  5,   8,   1,   4]], dtype=int64)

#without valence B
#unchanged.

#Using VA/VB
#0.7099863201094391

#using en and bl
#acc=0.7346101231190151

# %% [markdown]
# ## Using LightGBM as a classifier

# %%
#import lightgbm as lgb# Default gradient boosting machine classifier
#model = lgb.LGBMClassifier(importance_type='gain',n_estimators=500)
#model

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier(n_estimators=500,importance_type='gain')

# %%
model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='gain', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=500, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
model.fit(X_new, y_new)
model.score(X_new,y_new)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 0.8071748878923767

# %%
preds = model.predict(X_test)
accuracy_score(preds,y_test)
# Out:
# 0.8071748878923767

# %%
from sklearn.metrics import plot_confusion_matrix
import matplotlib.font_manager as fm
from matplotlib.collections import QuadMesh

# %%
y_test.value_counts()
# Out:
# 1    120
# 0     82
# 2     11
# 3     10
# Name: Lowest distortion, dtype: int64

# %%
array = confusion_matrix(preds,y_test)

df_cm = pd.DataFrame(array, range(4), range(4))
# plt.figure(figsize=(10,7))
plt.title('Confusion Matrix')
sns.set(font_scale=1.4) # for label size
df_cm = pd.DataFrame(array, index=["Predicted cubic", "Predicted orthorhombic", "Predicted rhombohedral", "Predicted tetragonal"], columns=["True cubic", "True orthorhombic", "True rhombohedral", "True tetragonal"])
sns.heatmap(df_cm,cmap="PuRd",fmt = '.2f', annot=True, annot_kws={"size": 16}) # font size
plt.savefig('confusion_matrix.tif', bbox_inches='tight', pad_inches=2.0)
plt.show()

# %%
confusion_matrix(preds,y_test)
# Out:
# array([[ 64,   9,   1,   1],
#        [ 15, 106,   3,   2],
#        [  2,   4,   6,   3],
#        [  1,   1,   1,   4]], dtype=int64)

# %%
features = X_new.columns
importances = model.booster_.feature_importance(importance_type='gain')
indices = np.argsort(importances)


#plt.figure(figsize=(6,7))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
features = X_new.columns
importances = model.booster_.feature_importance(importance_type='gain')
indices = np.argsort(importances)

l=['v(A$^{1+}$)','v(A$^{3+}$)','v(A$^{2+}$)','r(A$_{XII}$)','l(A-O)','l(B-O)','μ','r(A$_{VI}$)','τ','EN(A)','ΔENR','EN(B)','tG']
#plt.figure(figsize=(6,7))
plt.title('Feature Importances')
plt.barh(range(13), importances[indices], color='b', align='center')
plt.yticks(range(13), [i for i in l])
plt.xlabel('Relative Importance')
plt.savefig('relative_imp.tif', bbox_inches='tight', pad_inches=2.0)
plt.show()

# %%
features = X_new.columns
importances=model.booster_.feature_importance(importance_type='split')
indices = np.argsort(importances)

#plt.figure(figsize=(6,7))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# acc= 0.7889087656529516
#When we did not take valencies into account and took 3430 datapoints
#acc=0.7632508833922261

#On dropping rA at 6
#acc=0.7817531305903399

#On dropping 4 and 5
#acc=0.7960644007155635

#tg .82-1.1 and using tN
#acc=0.7847533632286996

#When using tN less than 4.18
#acc falls to 73%

# %% [markdown]
# ## When using gain for feature importance

# %%
# Goldschmidt Tolerance
# EN diff with radius
# EN of A
# EN of B
# tN

# %% [markdown]
# ## When using split for feature importance

# %%
# EN diff with radius
# Goldschmidt Tolerance
# Bond Length of B
# EN of B
# EN of A

# %% [markdown]
# ## Using Plotly to visualize clusters

# %%
#import plotly
#import plotly.express as px

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['Goldschmidt Tolerance'],z=wp1['tN'],color=categorical['Lowest distortion'])
#ig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['Goldschmidt Tolerance'],z=wp1['EN of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['Goldschmidt Tolerance'],z=wp1['EN of A'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['EN of B'],z=wp1['Bond length of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['EN of A'],z=wp1['Bond length of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN of B'], y=wp1['Goldschmidt Tolerance'],z=wp1['Bond length of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN of A'], y=wp1['Goldschmidt Tolerance'],z=wp1['Bond length of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN of A'], y=wp1['EN of B'],z=wp1['Bond length of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN of A'], y=wp1['Goldschmidt Tolerance'],z=wp1['EN of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=wp1['EN diff with radius'], y=wp1['EN of A'],z=wp1['EN of B'],color=categorical['Lowest distortion'])
#fig.show()

# %%
#truedf=wp1[wp1['In literature']==True]

# %%
#true_categorical=categorical[categorical['In literature']==True]

# %%
#categorical

# %%
#true_categorical

# %%
#fig = px.scatter_3d(x=truedf['EN diff with radius'], y=truedf['EN of A'],z=truedf['EN of B'],color=true_categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=truedf['EN of A'], y=truedf['Goldschmidt Tolerance'],z=truedf['EN of B'],color=true_categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=truedf['EN of A'], y=truedf['EN of B'],z=truedf['Bond length of B'],color=true_categorical['Lowest distortion'])
#fig.show()

# %%
#fig = px.scatter_3d(x=truedf['EN of A'], y=truedf['Goldschmidt Tolerance'],z=truedf['Bond length of B'],color=true_categorical['Lowest distortion'])
#fig.show()

# %%
import shap
shap_values = shap.TreeExplainer(model).shap_values(X_new)
#shap.summary_plot(shap_values, X_new)

# %% [markdown]
# ## SHAP summary plot for each crystal structure

# %%
#Cubic

# %%
shap.summary_plot(shap_values[0], X_new)
#plt.savefig('cubic.tif', bbox_inches='tight', pad_inches=1.0)

# %%
# Orthorhombic

# %%
shap.summary_plot(shap_values[1], X_new,show=False)
plt.savefig('orthorhombic.tif', bbox_inches='tight', pad_inches=1.0)

# %%
# Rhombohedral

# %%
shap.summary_plot(shap_values[2], X_new, show=False)
plt.savefig('rhombohedral.tif', bbox_inches='tight', pad_inches=1.0)

# %%
# Tetragonal

# %%
shap.summary_plot(shap_values[3], X_new,show=False)
plt.savefig('tetragonal.tif', bbox_inches='tight', pad_inches=1.0)

# %% [markdown]
# ## SHAP dependence graph for top variables

# %% [markdown]
# ### For Cubic

# %%
#shap.dependence_plot('EN diff with radius', shap_values[0], X_new)

# %%
#shap.dependence_plot('EN of A', shap_values[0], X_new)

# %%
#shap.dependence_plot('Goldschmidt Tolerance', shap_values[0], X_new)

# %%
#shap.dependence_plot('EN of B', shap_values[0], X_new)

# %%
#shap.dependence_plot('Bond length of B', shap_values[0], X_new)

# %% [markdown]
# ## For Orthorhombic

# %%
#shap.dependence_plot('EN diff with radius', shap_values[1], X_new)

# %%
#shap.dependence_plot('EN of A', shap_values[1], X_new)

# %%
#shap.dependence_plot('Goldschmidt Tolerance', shap_values[1], X_new)

# %%
#shap.dependence_plot('EN of B', shap_values[1], X_new)

# %%
#shap.dependence_plot('Bond length of B', shap_values[1], X_new)

# %% [markdown]
# ## For Rhombohedral

# %%
#shap.dependence_plot('EN diff with radius', shap_values[2], X_new)

# %%
#shap.dependence_plot('EN of A', shap_values[2], X_new)

# %%
#shap.dependence_plot('Goldschmidt Tolerance', shap_values[2], X_new)

# %%
#shap.dependence_plot('EN of B', shap_values[2], X_new)

# %%
#shap.dependence_plot('Bond length of B', shap_values[2], X_new)

# %% [markdown]
# ## For Tetragonal

# %%
#shap.dependence_plot('EN diff with radius', shap_values[3], X_new)

# %%
#shap.dependence_plot('EN of A', shap_values[3], X_new)

# %%
#shap.dependence_plot('Goldschmidt Tolerance', shap_values[3], X_new)

# %%
#shap.dependence_plot('EN of B', shap_values[3], X_new)

# %%
#shap.dependence_plot('Bond length of B', shap_values[3], X_new)
